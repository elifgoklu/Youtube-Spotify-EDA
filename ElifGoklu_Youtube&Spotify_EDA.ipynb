# %% [markdown]
# ## <p style="background-color:DarkSlateBlue; font-family:'Lucida Fax', serif; font-size:300%; text-align:center; border-radius: 10px; color: white;">Exploratory Data Analysis | EDA 🔍🔎</p>

# %% [markdown]
# # YouTube & Spotify Exploratory Data Analysis Project

# %% [markdown]
# # <div style="border-top: 3px solid DarkSlateBlue; margin: 10px 0;"></div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
#     <style>
#         .info {
#             font-size: 1.2em; /
#             margin-top: 20px; /
#         }
#     </style>
# </head>
# <body>
#     <div style="text-align: right;">
#         <img src="social.jpg" alt="Description" style="width:500px; float: right; margin-left: 20px;">
#          <br><br>
#         <p><strong style="color: DarkSlateBlue;">FIRST NAME:</strong> <span class="info">ELIF</span></p>
#         <p><strong style="color: DarkSlateBlue;">LAST NAME:</strong> <span class="info">GOKLU</span></p>
#         <p><strong style="color: DarkSlateBlue;">COURSE TAKEN:</strong> <span class="info">DATA ANALYST</span></p>
#         <p><strong style="color: DarkSlateBlue;">COURSE PROVIDER:</strong> <span class="info">KODLASAM</span></p>
#     </div>
# </body>
# </html>

# %% [markdown]
# # <div style="border-top: 3px solid DarkSlateBlue; margin: 10px 0;"></div>

# %% [markdown]
# ### <font color='SlateBlue'> LET'S GET TO KNOW THE DATA: </font>

# %% [markdown]
# *This dataset contains statistical information about songs by world-renowned artists, including metrics for listens, views, and likes on YouTube and Spotify platforms.

# %% [markdown]
# **<font color='DarkBlue'>Track**: The name of the song as seen on the Spotify platform.
#
# **<font color='DarkBlue'>Artist**: The name of the artist.
#
# **<font color='DarkBlue'>Url_spotify**: The artist's URL.
#
# **<font color='DarkBlue'>Album**: The album where the song is located.
#
# **<font color='DarkBlue'>Album_Type**: Indicates whether the song was released as a single or as part of an album on Spotify.
#
# **<font color='DarkBlue'>URL**: A Spotify link used to find the song via API.
#
# **<font color='DarkBlue'>Danceability**: Defines a song's suitability for dancing based on a combination of musical elements such as tempo, rhythm stability, emphasis strength, and overall regularity. A value of 0.0 is the least danceable and 1.0 is the most danceable.
#
# **<font color='DarkBlue'>Energy**: A measure between 0.0 and 1.0 representing the perceived intensity and activity of the song. Energetic tracks are usually fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low.
#
# **<font color='DarkBlue'>Key**: Specifies the tonality of the track. Integer values correspond to pitches using the standard Pitch Class notation. For example, 0 = C, 1 = C♯/D♭, 2 = D. If no key is detected, the value is -1.
#
# **<font color='DarkBlue'>Loudness**: The overall loudness of a track in decibels (dB). Loudness values are averaged across the track and are useful for comparing the relative loudness of tracks. Loudness is the primary psychological correlate of the physical strength (amplitude) of sound. Values typically range between -60 and 0 dB.
#
# **<font color='DarkBlue'>Speechiness**: Detects the presence of spoken words in a track. The more speech-like a recording is (e.g., talk show, audi

# %% [markdown]
# ### 🕵️‍♀️ Downloading Required Libraries and Importing the Data<a class="anchor" id="import"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
# Importing Data:
df=pd.read_csv('Spotify_Youtube.csv')
df.head(5)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %% [markdown]
# ## 👀 Quick View

# %%
#Checking the Size of the Data
df.shape
# Out:
# (20718, 28)

# %%
#Checking the Column Information
df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
df.describe().style.background_gradient(cmap="winter_r")
# Out:
# <style type="text/css">
# #T_6312e_row0_col0, #T_6312e_row0_col1, #T_6312e_row0_col2, #T_6312e_row0_col3, #T_6312e_row0_col4, #T_6312e_row0_col5, #T_6312e_row0_col6, #T_6312e_row0_col7, #T_6312e_row0_col8, #T_6312e_row0_col9, #T_6312e_row0_col10, #T_6312e_row7_col0, #T_6312e_row7_col11, #T_6312e_row7_col12, #T_6312e_row7_col13, #T_6312e_row7_col14, #T_6312e_row7_col15 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# ...

# %%
df["Channel"].unique()
# Out:
# array(['Gorillaz', 'Dom Dolla', 'SalvaMuñox', ..., 'ThxSoMch',
#        'ThxSoMch - Topic', 'SICK LEGEND - Topic'], dtype=object)

# %%
#Data Type Checking 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
# In the comments information, the data represents the number of comments:
df.rename(columns={'Comments': 'Comment Count'}, inplace=True)
# Correcting Column Names
df.rename(columns={'official_video': 'Official Video'}, inplace=True)

# %% [markdown]
# ### 🧼 Data Cleaning

# %%
# Removing the Unnecessary Unnamed Column
df= df.drop(["Unnamed: 0"], axis=1)
df.head(5)
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
# Checking Null Values with Corresponding Percentages
df.isnull().sum()/len(df)
# Out:
# Artist              0.000000
# Url_spotify         0.000000
# Track               0.000000
# Album               0.000000
# Album_type          0.000000
# Uri                 0.000000
# Danceability        0.000097
# Energy              0.000097
# Key                 0.000097
# Loudness            0.000097
# Speechiness         0.000097
# Acousticness        0.000097
# Instrumentalness    0.000097
# Liveness            0.000097
# Valence             0.000097
# Tempo               0.000097
# Duration_ms         0.000097
# Url_youtube         0.022686
# Title               0.022686
# Channel             0.022686
# Views               0.022686
# Likes               0.026113
# Comment Count       0.027464
# Description         0.042282
# Licensed            0.022686
# Official Video      0.022686
# Stream              0.027802
# dtype: float64

# %%
# Filtering the Data to be Used
df = df[['Artist', 
    #'Url_spotify', 
    'Track', 'Album', 'Album_type', 
    #'Uri',
    'Danceability', 
    #'Energy', 'Key', 'Loudness', 
    #'Speechiness', 
    #'Acousticness', 'Instrumentalness', 'Liveness', 
    'Valence', 
    #'Tempo', 
    'Duration_ms', 
    #'Url_youtube', 
    'Title', 'Channel', 'Views', 'Likes', 'Comment Count', 
    #'Description', 'Licensed', 
    'Official Video', 'Stream']].copy()

# %%
df.head(5)
# Out:
#      Artist                                          Track  \
# 0  Gorillaz                                 Feel Good Inc.
# 1  Gorillaz                                Rhinestone Eyes
# 2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                             On Melancholy Hill
# 4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type  Danceability  \
# 0                                     Demon Days      album         0.818
# 1                                  Plastic Beach      album         0.676
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                  Plastic Beach      album         0.689
# 4                                       Gorillaz      album         0.663
#
#    Valence  Duration_ms                                              Title  \
# 0    0.772     222640.0         Gorillaz - Feel Good Inc. (Official Video)
# ...

# %%
# Removing Null Values:
df.dropna(inplace=True)

# %%
# Checking the Result
df.isnull().sum()
# Out:
# Artist            0
# Track             0
# Album             0
# Album_type        0
# Danceability      0
# Valence           0
# Duration_ms       0
# Title             0
# Channel           0
# Views             0
# Likes             0
# Comment Count     0
# Official Video    0
# Stream            0
# dtype: int64

# %%
df.shape
# Out:
# (19549, 14)

# %%
# Checking for Duplicate Values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Preprocessing

# %%
df.dtypes
# Out:
# Artist             object
# Track              object
# Album              object
# Album_type         object
# Danceability      float64
# Valence           float64
# Duration_ms       float64
# Title              object
# Channel            object
# Views             float64
# Likes             float64
# Comment Count     float64
# Official Video     object
# Stream            float64
# dtype: object

# %%
# Adjusting for Better Clarity in Visuals
df['Official Video'] = df['Official Video'].replace({True: 'Official', False: 'Not Official'})

# %%
# Representing Integer Values as Integers for More Accurate Data Types
df[["Likes","Comment Count","Views","Stream"]]=df[["Likes","Comment Count","Views","Stream"]].astype("int64")
df.dtypes
# Out:
# Artist             object
# Track              object
# Album              object
# Album_type         object
# Danceability      float64
# Valence           float64
# Duration_ms       float64
# Title              object
# Channel            object
# Views               int64
# Likes               int64
# Comment Count       int64
# Official Video     object
# Stream              int64
# dtype: object

# %%
# Separating Numeric Data
numerical_df = df.select_dtypes(include=['float64',"int64"])
numerical_df
# Out:
#        Danceability  Valence  Duration_ms      Views    Likes  Comment Count  \
# 0             0.818   0.7720     222640.0  693555221  6220896         169907
# 1             0.676   0.8520     200173.0   72011645  1079128          31003
# 2             0.695   0.5510     215150.0    8435055   282142           7399
# 3             0.689   0.5780     233867.0  211754952  1788577          55229
# 4             0.663   0.5250     340920.0  618480958  6197318         155930
# ...             ...      ...          ...        ...      ...            ...
# 20713         0.582   0.6580      94667.0      71678     1113              0
# 20714         0.531   0.6570     150857.0     164741     2019              0
# 20715         0.443   0.4190     136842.0      35646      329              0
# 20716         0.417   0.5390     108387.0       6533       88              0
# 20717         0.498   0.0787     181500.0     158697     2484              0
#
#            Stream
# 0      1040234854
# ...

# %%
# Calculating Song Durations in Minutes
df["Duration_min"] = (df['Duration_ms'] / 60000).round(2)

# %%
df["Duration_min"]
# Out:
# 0        3.71
# 1        3.34
# 2        3.59
# 3        3.90
# 4        5.68
#          ...
# 20713    1.58
# 20714    2.51
# 20715    2.28
# 20716    1.81
# 20717    3.02
# Name: Duration_min, Length: 19549, dtype: float64

# %% [markdown]
# ### 🧩HeatMap Correlation Analysis

# %%
# Separating Numeric Values
numerical_df = df.select_dtypes(include=['float64',"int64"])
numerical_df
# Out:
#        Danceability  Valence  Duration_ms      Views    Likes  Comment Count  \
# 0             0.818   0.7720     222640.0  693555221  6220896         169907
# 1             0.676   0.8520     200173.0   72011645  1079128          31003
# 2             0.695   0.5510     215150.0    8435055   282142           7399
# 3             0.689   0.5780     233867.0  211754952  1788577          55229
# 4             0.663   0.5250     340920.0  618480958  6197318         155930
# ...             ...      ...          ...        ...      ...            ...
# 20713         0.582   0.6580      94667.0      71678     1113              0
# 20714         0.531   0.6570     150857.0     164741     2019              0
# 20715         0.443   0.4190     136842.0      35646      329              0
# 20716         0.417   0.5390     108387.0       6533       88              0
# 20717         0.498   0.0787     181500.0     158697     2484              0
#
#            Stream  Duration_min
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(numerical_df.corr(),annot=True,cmap='BuPu_r')
plt.show()

# %% [markdown]
# ## 📊 📈 Visualizations

# %% [markdown]
# ### 💿 📀Percentage Distribution of Album Types

# %%
labels=df["Album_type"].unique()

# %%
labels=df["Album_type"].value_counts().index
sizes=df["Album_type"].value_counts().values
explode= [0.1] * len(sizes) 
colors = ['#DEB887','#5F9EA0','#FF1493','#ff9999','#66b3ff']

plt.pie(sizes, 
        explode=explode, 
        labels=labels, 
        colors=colors[:len(sizes)], 
        autopct="%1.1f%%", 
        startangle=140, 
        textprops={'fontsize': 10, 'fontweight': 'bold', 'color': 'navy'})
plt.title('Percantage Distribution of Album Types')
plt.show()

# %% [markdown]
# ### 💃⏱Distribution of Views by Album Type and Danceability

# %%
# Distribution of Views for Energetic Songs by Album Type

palette = {"Official": 'salmon', "Not Official": 'rebeccapurple'}
g = sns.relplot(data=df, x="Danceability", y="Views",hue="Official Video", col="Album_type", col_wrap=3, height=3, palette=palette)


# Showing Graph:
plt.show()

# %%
palette = {"Official": 'salmon', "Not Official": 'rebeccapurple'}
g = sns.relplot(data=df, x="Danceability", y="Stream",hue="Official Video", col="Album_type", col_wrap=3, height=3, palette=palette)


# Showing Graph
plt.show()

# %% [markdown]
# ### 🎶🔊 Vance and DanceAbilitiy Histogram Graphs

# %%
df["Official Video"]
# Out:
# 0        Official
# 1        Official
# 2        Official
# 3        Official
# 4        Official
#            ...
# 20713    Official
# 20714    Official
# 20715    Official
# 20716    Official
# 20717    Official
# Name: Official Video, Length: 19549, dtype: object

# %%
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
sns.set_palette('coolwarm')
sns.set_theme(style='darkgrid')
sns.histplot(x=df["Valence"],color="aqua")

plt.subplot(1, 2, 2)
sns.set_palette('coolwarm')
sns.set_theme(style='darkgrid')
sns.histplot(x=df["Danceability"],color="aqua")
plt.show()

# %%
df.head()
# Out:
#      Artist                                          Track  \
# 0  Gorillaz                                 Feel Good Inc.
# 1  Gorillaz                                Rhinestone Eyes
# 2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                             On Melancholy Hill
# 4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type  Danceability  \
# 0                                     Demon Days      album         0.818
# 1                                  Plastic Beach      album         0.676
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                  Plastic Beach      album         0.689
# 4                                       Gorillaz      album         0.663
#
#    Valence  Duration_ms                                              Title  \
# 0    0.772     222640.0         Gorillaz - Feel Good Inc. (Official Video)
# ...

# %% [markdown]
# ### 🎤 🎶 Top 10 Songs

# %%
# Preparing the Parameters for the Top 10 Lists Based on Different Metrics
df_top10=df.groupby('Track').agg({"Likes":"sum",'Views':'sum',"Comment Count":"sum","Stream":"sum"})
df_top10['Rate'] = df_top10['Likes'] / df_top10['Views']
df_top10
# Out:
#                                Likes      Views  Comment Count     Stream  \
# Track
# !ly (feat. Coez)               89060   11828802           1628   52628204
# #1 - Colby O'Donis Remix      319099   50109737          12359     561794
# #3                            157657   18316658           3262   45002482
# #41                            20527    4160936           1248   34528391
# #Ysya2020 Vol. 5 - Silbando    35206    1866183            521   26297019
# ...                              ...        ...            ...        ...
# 高嶺の花子さん                       318430   73883526          10420   69373615
# 그대라는 시                         49455    3513557            531   84972553
# 눈,코,입 (Eyes, Nose, Lips)     2443798  237696728          94634  112300290
# 러시안 룰렛 Russian Roulette      2604330  244786739         133342  151307068
# 링가링가 (RINGA LINGA)           1295454  138130315          53205   36450721
#
#                                  Rate
# Track
# ...

# %%
df_top10=df_top10.reset_index()

# %%
# Top 10 Most Viewed Songs
df_views=df_top10.sort_values(by='Views',ascending=False).head(10)
# Top 10 Most Liked Songs
df_likes=df_top10.sort_values(by='Likes',ascending=False).head(10)
# op 10 Songs with the Highest Like-to-View Ratio
df_top10['Rate'] = df_top10['Likes'] / df_top10['Views']
df_rates=df_views.sort_values(by='Rate', ascending=False).head(10)
# Top 10 Most Commented Songs
df_comments=df_top10.sort_values(by='Comment Count', ascending=False).head(10)
# Top 10 Most Played Songs
df_stream=df_top10.sort_values(by='Stream', ascending=False).head(10)
df_stream
# Out:
#                                                        Likes       Views  \
# Track
# Closer                                               7422189  1032683678
# Can't Hold Us (feat. Ray Dalton)                    19812415  3036616404
# Sunflower - Spider-Man: Into the Spider-Verse       27499619  3954778068
# Happier                                             31041744  2494989607
# STAY (with Justin Bieber)                           20262821  1362416985
# Señorita                                            39692236  2975300305
# The Middle                                           3786019   466742615
# Eastside (with Halsey & Khalid)                      5698967  1269443225
# lovely (with Khalid)                                48852042  3442782701
# Enemy (with JID) - from the series Arcane Leagu...  20918740  1185281403
#
#                                                     Comment Count      Stream  \
# Track
# ...

# %%
# Most Played Songs
plt.figure(figsize=(12,7))
plt.subplot(2, 2, 1)
sns.barplot(x='Stream',y='Track',data=df_stream,color='Salmon')
plt.xticks(fontsize=8,rotation=0)
plt.yticks(fontsize=11,rotation=0)

# Most Viewed Songs
plt.subplot(2, 2, 2)
sns.barplot(x='Views',y='Track',data=df_views,color='Salmon')
plt.yticks(fontsize=11,rotation=0)
plt.xticks(fontsize=10,rotation=0)

# Most Played Songs by Number of Likes
plt.subplot(2, 2, 3)
sns.barplot(x='Likes',y='Track',data=df_likes,color='Salmon')
plt.yticks(fontsize=11,rotation=0)
plt.xticks(fontsize=10,rotation=0)

# Most Commented Songs
plt.subplot(2, 2, 4)
sns.barplot(x='Comment Count',y='Track',data=df_comments,color='Salmon')
plt.yticks(fontsize=11,rotation=0)
plt.xticks(fontsize=10,rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 👩🏼‍🎤 👨🏼‍🎤🎙️Hit Singers

# %%
# Preparing the Parameters for the Top 10 Lists Based on Different Metrics
df_singer10=df.groupby('Artist').agg({"Likes":"sum",'Views':'sum',"Comment Count":"sum","Stream":"sum"})
df_singer10.reset_index()
# Out:
#               Artist     Likes       Views  Comment Count      Stream
# 0               $NOT   2747163   110784903          81497  1127638002
# 1        $uicideboy$   3576621   334135108          65127  2126748130
# 2           (G)I-DLE  24462963  1754953941        1456246  1304212458
# 3             *NSYNC   4233423  1027832862         225267  1427833756
# 4          070 Shake   2013005    96099359          41366   464748617
# ...              ...       ...         ...            ...         ...
# 2035       will.i.am  13853418  2830800713         780798  1362307072
# 2036  Ángela Aguilar  10294757  1385295291         281484   591152036
# 2037            Ñejo   4348910   626680824         103997   527516023
# 2038      Ñengo Flow   6760340   812726315         153443  1497314419
# 2039        Øneheart   1272167    34623310          25667   255199435
#
# [2040 rows x 5 columns]

# %%
# Top 10 Most Viewed Singers
singer_views=df_singer10.sort_values(by='Views',ascending=False).head(10)
# Top 10 Most Liked Singers
singer_likes=df_singer10.sort_values(by='Likes',ascending=False).head(10)
# Top 10 Most Commented Singers
singer_comments=df_singer10.sort_values(by='Comment Count', ascending=False).head(10)
# Top 10 Monst Listened Singers
singer_stream=df_singer10.sort_values(by='Stream', ascending=False).head(10)
singer_stream
# Out:
#                     Likes        Views  Comment Count       Stream
# Artist
# Post Malone      53974744   6394420209        1374279  15251263853
# Ed Sheeran       83543319  15460207769        2520822  14394881557
# Dua Lipa         62627677   8216339307        1326153  13408076274
# The Weeknd       47299512   6859509344        1429064  12464283476
# Justin Bieber    78584348  10991060236        7259120  12097767422
# XXXTENTACION     44118638   2542795388        3047063  12011910355
# Imagine Dragons  72274477   9093785238        2004432  11858310928
# Coldplay         63157895   9997277884        2124370  11778478236
# Khalid           46881447   5398246275        1001265  11386839915
# Bruno Mars       59616146  10240919227        1924316  10897862950

# %%
# Top 10 Most Liked Singers Grahp
plt.figure(figsize=(12,7))
plt.subplot(2, 2, 1)
sns.barplot(x='Stream',y='Artist',data=singer_stream,color='Plum')
plt.xticks(fontsize=10,rotation=0)
plt.yticks(fontsize=11,rotation=0)

# Top 10 Most Viewed Singers Graph
plt.subplot(2, 2, 2)
sns.barplot(x='Views',y='Artist',data=singer_views,color='Plum')
plt.yticks(fontsize=11,rotation=0)
plt.xticks(fontsize=10,rotation=0)

# Top 10 Most Liked Singers Graph
plt.subplot(2, 2, 3)
sns.barplot(x='Likes',y='Artist',data=singer_likes,color='Plum')
plt.yticks(fontsize=11,rotation=0)
plt.xticks(fontsize=10,rotation=0)

# Top 10 Monst Listened Singers Graph
plt.subplot(2, 2, 4)
sns.barplot(x='Comment Count',y='Artist',data=singer_comments,color='Plum')
plt.yticks(fontsize=11,rotation=0)
plt.xticks(fontsize=10,rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📺🔉👂View and Listen Distribution Graphs for Songs Under 10 Minutes by Album Types

# %%
Duration=df[(df["Duration_min"]<=10)]

# %%
Duration["Rate"]=Duration["Stream"]/Duration["Views"]
Duration["Rate"].mean()
# Out:
# 2669.348857242675

# %%
color_palette = {
    'Official': '#9ACD32',  # Yellow Green
    'Not Official': '#FF1493'  # Deep pink
}
sns.relplot(data=Duration, x="Duration_min", y="Stream", hue="Official Video",palette=color_palette, col="Album_type");

# %%
sns.relplot(data=Duration, x="Duration_min", y="Views", hue="Official Video",palette=color_palette, col="Album_type");
